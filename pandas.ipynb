# %%
import pandas as pd

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('survey_results_public.csv', index_col='Respondent', na_values=na_vals) # This is to read the file from the path
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column') # importing the schema
# You can also import any disctionary inside any dataframe. df2 = pd.DataFrame(dictionary_name)

# %%
df.shape # This is a property and not a method shows the dimensions of the dataframe
df.info() # This method returns the information about the dataframe like datatypes of rows, etc.

# %%
# To set the number of rows and columns to be displayed:
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 80)

# %%
df.head() # you also have df.tail()

# %%
schema_df.head(40)

# %%
df['MainBranch'] # To access value of a single column (You can access series with dot operator as well)

# %%
type(df['Respondent']) # Each column is a series. It means rows of a single column. Multiple series form a dataframe

# %%
df[['Respondent', 'MainBranch']] # Leaving a list of columns that you want to extract.
# When we get multiple columns, we get dataframe in return, not series

# %%
df.columns # This method returns all the columns

# %%
df.iloc[0] # To access rows, you gotta use iLoc (index-location)

# %%
df.iloc[[0,1]] # to get a list of rows

# %%
df.iloc[[0,1], 2] # df.iloc[row,col] df.loc - to access rows and columns by names/strings.

# %%
df.loc[0,'Respondent'] # df.loc[row,col]

# %%
type(df.shape) # df.shape returns a tuple

# %%
 df['Hobbyist'].value_counts() # Here, we can get the counts of unique items

# %%
df.loc[0:2, 'Hobbyist': 'Employment'] # Slicing is supported in loc. The last item is inclusive

# %%
df.set_index('Respondent') # To set the index. This just marks the column as index. To modify and replace original index
# please run df.set_index('Respondent', inplace=True).
# Once you set the index, you lose the original indices. Index are nothing but row labels

# %%
df.index

# %%
df.reset_index(inplace=True) # To reset the indices
# You can also set index while loading the data into data into dataframe

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
# schema_df.set_index('Column', inplace=True)

# %%
df.head()

# %%
schema_df.sort_index(inplace=True) # To sort the index To sort in descending order, pass descending=False. Passing inplace=True 
# makes the changes  to the source

# %%
filt = df['Country'] == 'India' # Setting up the filter

# %%
df[filt] # Approach 1 of applying filter to the dataframe. Wit this approach, you get all cols matching the criteria
df.loc[filt] # Approach 2 of applying filter to the dataframe. With this approach, you can get specific cols

# %%
filt2 = (df['Country'] == 'India') & (df['Hobbyist'] == 'Yes') # Use of & to apply and operation between filtering criteria
df.loc[~filt2] # By just putting ~ in front of the filter name, you can all rows which doesn't match the filter

# %%
# pd.set_option('display.max_columns', 100)

high_salary = (df['ConvertedComp'] > 70000)
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]

# %%
countries = ['United States', 'India', 'United Kingdome', 'Germany', 'Canada']
filt3 = df['Country'].isin(countries) # You can pass a list of values that you want to compare with
df.loc[filt3]

# %%
df['LanguageWorkedWith']
filt4 = df['LanguageWorkedWith'].str.contains('Python', na=False) # setting up filter to filter a string
df.loc[filt4, ['Country', 'LanguageWorkedWith']]

# %%
# Renaming Salary column
df.rename(columns={'ConvertedComp': 'Salary_USD'}, inplace=True)
df.head()
df['Salary_USD']
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: Salary_USD, Length: 88883, dtype: float64

# %%
# Replace Yes/no of Hobbyist column with True or False
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': False})
df.head()
# Out:
#    Respondent                                         MainBranch  Hobbyist  \
# 0           1             I am a student who is learning to code      True
# 1           2             I am a student who is learning to code     False
# 2           3  I am not primarily a developer, but I write co...      True
# 3           4                     I am a developer by profession     False
# 4           5                     I am a developer by profession      True
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
# To find lowest salary
df['Salary_USD'].min()
# Out:
# 0.0

# %%
# To find lowest age
df.columns
df['Age'].min
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'Salary_USD', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
# Sorting
df.sort_values(by=['Country','ConvertedComp'], ascending=[True,False] ,inplace=True)
df.head(10)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 62723       63129                     I am a developer by profession      Yes
# 50172       50499  I am not primarily a developer, but I write co...      Yes
# 39018       39258                     I am a developer by profession      Yes
# 58082       58450                     I am a developer by profession      Yes
# 7056         7085                     I am a developer by profession      Yes
# 22327       22450                     I am a developer by profession       No
# 48122       48436                     I am a developer by profession       No
# 10697       10746                     I am a developer by profession      Yes
# 8112         8149                     I am a developer by profession      Yes
# 29560       29736                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...

# %%
# To fetch nlargest, to fetch smallest its df.nsmallest(n, 'column_name')
df.nlargest(10,'ConvertedComp')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 25833       25983                     I am a developer by profession      Yes
# 87353       87896                     I am a developer by profession      Yes
# 21895       22013                     I am a developer by profession      Yes
# 28080       28243                     I am a developer by profession      Yes
# 72274       72732  I am not primarily a developer, but I write co...       No
# 77665       78151                     I am a developer by profession      Yes
# 79701       80200                     I am a developer by profession      Yes
# 51798       52132                     I am a developer by profession      Yes
# 75088       75561                     I am a developer by profession      Yes
# 32056       32250                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
# --------------------------------------------- Begining of Anlaysis ------------------------------------

df['ConvertedComp'].median()
df.median()
# Out:
# Respondent       44442.0
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
df['Country'].value_counts().head(80)
# Out:
# United States                           20949
# India                                    9061
# Germany                                  5866
# United Kingdom                           5737
# Canada                                   3395
# France                                   2391
# Brazil                                   1948
# Poland                                   1922
# Australia                                1903
# Netherlands                              1852
# Russian Federation                       1694
# Spain                                    1604
# Italy                                    1576
# Sweden                                   1274
# Switzerland                               978
# Israel                                    952
# Turkey                                    949
# Pakistan                                  923
# Ukraine                                   868
# Austria                                   839
# ...

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
filt = schema_df['Column'] == 'SocialMedia'
schema_df[filt]
# Out:
#          Column                                 QuestionText
# 61  SocialMedia  What social media site do you use the most?

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
country_grp = df.groupby('Country')
country_grp['SocialMedia'].value_counts(normalize=True).loc['Germany']
# Out:
# SocialMedia
# WhatsApp                    0.246966
# YouTube                     0.178374
# Reddit                      0.169732
# Twitter                     0.159250
# I don't use social media    0.092129
# Facebook                    0.074292
# Instagram                   0.048547
# LinkedIn                    0.025929
# Snapchat                    0.001839
# VK ВКонта́кте               0.001471
# WeChat 微信                   0.001471
# Name: SocialMedia, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['United States']
# Out:
# 110000.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).head(80)
# Out:
#                                          median           mean
# Country
# Afghanistan                              6222.0  101953.333333
# Albania                                 10818.0   21833.700000
# Algeria                                  7878.0   34924.047619
# Andorra                                160931.0  160931.000000
# Angola                                   7764.0    7764.000000
# Antigua and Barbuda                         NaN            NaN
# Argentina                               17760.0   29467.265306
# Armenia                                 19692.0   24691.733333
# Australia                               79783.0  171541.116279
# Austria                                 51559.0   83955.639604
# Azerbaijan                              15858.0   15785.750000
# Bahamas                                     NaN            NaN
# Bahrain                                 15912.0   23934.000000
# Bangladesh                               8764.0   21249.652000
# ...

# %%
filt = df['Country'] == 'United States'
df[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 10083

# %%
# Challenge Approach 1
df1 = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
df2 = df['Country'].value_counts()
df3 = (df1 / df2)*100
df3.loc['United States']
# Out:
# 48.13117571244451

# %%
# Challenge Approach 2
df1 = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
df2 = df['Country'].value_counts()
df3 = pd.concat([df1, df2], axis='columns')
df3.rename(columns={"LanguageWorkedWith": "People_know_python", "Country": "PeopleResponded"}, inplace=True)
df3['Python_dev_%'] = (df3['People_know_python'] / df3['PeopleResponded'])*100
df3
df3.loc['United States']
df3.sort_values(by=['PeopleResponded','Python_dev_%',], ascending=[False,False], inplace=True)
df3
# Out:
#                                   People_know_python  PeopleResponded  \
# United States                                  10083            20949
# India                                           3105             9061
# Germany                                         2451             5866
# United Kingdom                                  2384             5737
# Canada                                          1558             3395
# ...                                              ...              ...
# North Korea                                        0                1
# Papua New Guinea                                   0                1
# Saint Kitts and Nevis                              0                1
# Saint Vincent and the Grenadines                   0                1
# Tonga                                              0                1
#
#                                   Python_dev_%
# United States                        48.131176
# ...

# %%
df.dropna(axis='index', subset=['ConvertedComp'])
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 6           I am not primarily a developer, but I write co...      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
# ...                                                       ...      ...
# 88878                          I am a developer by profession      Yes
# 88879                          I am a developer by profession      Yes
# 88881                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
# 88883                          I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 3                                Never
# ...

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].replace({'Less than 1 year': 1, 'More than 50 years': 50})
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %%
df['YearsCode'].describe()
# Out:
# count    87938.000000
# mean        11.676226
# std          9.127689
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         15.000000
# max         50.000000
# Name: YearsCode, dtype: float64
